# %% [markdown]
# <a href="https://colab.research.google.com/github/lhamini/539_office_hours/blob/main/Colab_Crash_Course.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Colab Crash Course

# %% [markdown]
# # Cells
# A notebook is a list of cells. Cells contain either explanatory text or executable code and its output. Click a cell to select it.

# %% [markdown]
# ## Code cells
# Below is a **code cell**. Once the toolbar button indicates CONNECTED, click in the cell to select it and execute the contents in the following ways:
#
# * Click the **Play icon** in the left gutter of the cell;
# * Type **Cmd/Ctrl+Enter** to run the cell in place;
# * Type **Shift+Enter** to run the cell and move focus to the next cell (adding one if none exists); or
# * Type **Alt/Option+Enter** to run the cell and insert a new code cell immediately below it.
#
# There are additional options for running some or all cells in the **Runtime** menu.

# %%
a = 25

# %%
# b

# %% [markdown]
# ## Text cells
#
#
#
# This is a **text cell**. You can **double-click** to edit this cell. Text cells
# use markdown syntax. To learn more, see our [markdown
# guide](/notebooks/markdown_guide.ipynb).
#
# You can also add math to text cells using [LaTeX](http://www.latex-project.org/)
# to be rendered by [MathJax](https://www.mathjax.org). Just place the statement
# within a pair of **\$** signs. For example `$\sqrt{3x-1}+(1+x)^2$` becomes
# $\sqrt{3x-1}+(1+x)^2.$

# %% [markdown]
# ## Adding and moving cells
# You can add new cells by using the **+ CODE** and **+ TEXT** buttons that show when you hover between cells. These buttons are also in the toolbar above the notebook where they can be used to add a cell below the currently selected cell.
#
# You can move a cell by selecting it and clicking **Cell Up** or **Cell Down** in the top toolbar.

# %% [markdown]
# ## Tab-completion and exploring code
# ​
# Colab provides tab completion to explore attributes of Python objects, as well as to quickly view documentation strings. As an example, first run the following cell to import the  [`numpy`](http://www.numpy.org) module.

# %%
import numpy as np

# %% [markdown]
# If you now insert your cursor after ``np.random.`` and press **Tab**, you will see the list of available completions within the ``np.random`` submodule.

# %%
np.random.randint(0, 10)
# Out:
# 4

# %% [markdown]
# If you type an open parenthesis, you will see a pop-up of its documentation string:

# %%
np.random.randint()

# %% [markdown]
# To open the documentation in a persistent pane at the bottom of your screen, add a **?** after the object or method name and execute the cell using **Shift+Enter**:

# %%
np.random.randint?

# %% [markdown]
# ## Plotting and charts

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 100 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')

plt.title("Plotting")
plt.show()

# %% [markdown]
# ## Forms
#
# Forms provide an easy way to parameterize code. From a code cell, select **Insert → Add form field**.  When you change the value in a form, the corresponding value in the code will change.

# %%
#@title String fields

text = 'Hi 539 Team!' #@param {type:"string"}
dropdown = 'Yes' #@param ["Yes", "No"]
text_and_dropdown = '2nd option with 1st option' #@param ["1st option", "2nd option", "3rd option"] {allow-input: true}

print(text)
print(dropdown)
print(text_and_dropdown)
# Out:
# Hi 539 Team!
# Yes
# 2nd option with 1st option

# %% [markdown]
# ## Importing a library that is not in Colaboratory
#
# To import a library that's not in Colaboratory by default, you can use `!pip install` or `!apt-get install`.

# %%
# !pip install -q matplotlib-venn

# %% [markdown]
# ## System aliases
#
# Jupyter includes shortcuts for common operations, such as ls:

# %%
# !pwd

# %%
pwd
# Out:
# '/content'

# %%
# !ls /content
# Out:
# sample_data

# %%
ls /content/
# Out:
# sample_data/

# %%
# nvidia-smi

# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %% [markdown]
# That `!ls` probably generated a large output. You can select the cell and clear the output by either:
#
# 1. Clicking on the clear output button (x) in the toolbar above the cell; or
# 2. Right clicking the left gutter of the output area and selecting "Clear output" from the context menu.

# %% [markdown]
# # Integration with Drive
#
# Colaboratory is integrated with Google Drive. It allows you to share, comment, and collaborate on the same document with multiple people:
#
# * The **SHARE** button (top-right of the toolbar) allows you to share the notebook and control permissions set on it.
#
# * **File->Make a Copy** creates a copy of the notebook in Drive.
#
# * **File->Save** saves the File to Drive. **File->Save and checkpoint** pins the version so it doesn't get deleted from the revision history.
#
# * **File->Revision history** shows the notebook's revision history.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
ls
# Out:
# gdrive/  sample_data/

# %%
ls "gdrive/MyDrive/539 - Milestone i"
# Out:
# 539_OH.pptx  teams.gsheet

# %% [markdown]
# ## Magics
#
# Special commands that allow you to run special tasks
#
# https://nbviewer.jupyter.org/github/ipython/ipython/blob/1.x/examples/notebooks/Cell%20Magics.ipynb

# %%
# %%html
# <marquee style='width: 50%; color: red;'><b>539 Office Hours</b></marquee>
# Out:
# <marquee style='width: 50%; color: red;'><b>539 Office Hours</b></marquee>

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %conda  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %shell  %store  %sx  %system  %tb  %tensorflow_version  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%bigquery  %%capture  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%markdown  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%shell  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.

# %% [markdown]
# ### Timing code

# %%
# Line
import numpy as np

# %timeit np.linalg.eigvals(np.random.rand(100,100))
# Out:
# 14 ms ± 3.74 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# Cell
# %%time
a = 0
for i in range(10000000):
  a += i
# Out:
# CPU times: user 1.29 s, sys: 418 µs, total: 1.29 s
# Wall time: 1.31 s

# %% [markdown]
# Groq or gemeni Secret

# %%
#!pip install langchain_groq

# %%
from langchain_groq import ChatGroq
from google.colab import userdata

llm = ChatGroq(
    groq_api_key=userdata.get('GROQ_API_KEY'),
    model_name='llama3-70b-8192')

# %%
llm.invoke('List best practices to start a EDA project')
# Out:
# AIMessage(content="Here are some best practices to start an Exploratory Data Analysis (EDA) project:\n\n**1. Define the Problem or Question**:\nClearly articulate the problem or question you want to address with your EDA project. This will help you stay focused and ensure that your analysis is relevant and meaningful.\n\n**2. Collect and Review Relevant Data**:\nGather all relevant data sources, including datasets, documents, and other materials. Review the data to understand its structure, quality, and potential limitations.\n\n**3. Establish a Clear Objective**:\nDetermine what you want to achieve with your EDA project. Is it to identify patterns, trends, or correlations? Are you trying to answer a specific question or solve a problem?\n\n**4. Choose the Right Tools and Technologies**:\nSelect the most appropriate tools, software, and programming languages for your EDA project. Familiarize yourself with the tools and technologies you'll be using.\n\n**5. Develop a Structured Approach**:\nBreak down your EDA project into manageable tasks and create a structured approach to guide your analysis. This will help you stay organized and ensure that you cover all aspects of the data.\n\n**6. Explore and Clean the Data**:\nExplore the data to understand its distribution, outliers, and missing values. Clean the data by handling missing values, removing duplicates, and transforming variables as needed.\n\n**7. Visualize the Data**:\nUse visualization techniques to understand the data's structure, patterns, and relationships. This will help you identify trends, correlations, and anomalies.\n\n**8. Identify Key Variables and Relationships**:\nIdentify the most important variables and relationships in the data. This will help you focus on the most relevant aspects of the data.\n\n**9. Perform Statistical Analysis**:\nApply statistical methods to quantify and model the relationships in the data. This may include hypothesis testing, confidence intervals, and regression analysis.\n\n**10. Document Your Process and Findings**:\nMaintain a record of your EDA process, including your approach, methods, and findings. This will help you replicate your results and share your insights with others.\n\n**11. Iterate and Refine**:\nEDA is an iterative process. Be prepared to refine your approach, adjust your methods, and revisit your findings as you learn more about the data.\n\n**12. Communicate Insights Effectively**:\nPresent your findings in a clear, concise, and actionable way. Use visualization and storytelling techniques to communicate insights to stakeholders.\n\n**13. Consider Ethical and Privacy Implications**:\nEnsure that your EDA project adheres to ethical standards and privacy regulations. Protect sensitive information and avoid biased or discriminatory analysis.\n\n**14. Plan for Data Storage and Management**:\nDevelop a plan for storing and managing the data, including data backup, security, and access controls.\n\n**15. Establish a Timeline and Budget**:\nDefine a realistic timeline and budget for your EDA project. This will help you stay on track and manage resources effectively.\n\nBy following these best practices, you'll be well on your way to conducting a successful EDA project that yields valuable insights and informs data-driven decision-making.", response_metadata={'token_usage': {'completion_tokens': 630, 'prompt_tokens': 19, 'total_tokens': 649, 'completion_time': 1.868891846, 'prompt_time': 0.006392939, 'queue_time': None, 'total_time': 1.8752847849999998}, 'model_name': 'llama3-70b-8192', 'system_fingerprint': 'fp_87cbfbbc4d', 'finish_reason': 'stop', 'logprobs': None}, id='run-c9502730-db88-4946-80b1-9f26bf85a41d-0')

# %% [markdown]
# ## pages
#
#
#
#
#
# *   colab.google
# *   colab.research.google.com
#
#
#
#
#
# https://colab.research.google.com/github/Tanu-N-Prabhu/Python/blob/master/Exploratory_data_Analysis.ipynb

# %% [markdown]
# ## dataset search
#
# https://datasetsearch.research.google.com/

# %%
#!pip install opendatasets

# %%
import opendatasets as od


# List all datasets
dataset_url = "https://www.kaggle.com/tunguz/us-elections-dataset"
od.download(dataset_url)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: eamini
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/tunguz/us-elections-dataset
# Downloading us-elections-dataset.zip to ./us-elections-dataset
# 100%|██████████| 133k/133k [00:00<00:00, 68.7MB/s]

# %% [markdown]
# ## Auto Plot and Tables

# %%
import pandas as pd
df = pd.read_csv("us-elections-dataset/1976-2020-president.csv", nrows=20)
df
# Out:
#     year     state state_po  state_fips  state_cen  state_ic        office  \
# 0   1976   ALABAMA       AL           1         63        41  US PRESIDENT
# 1   1976   ALABAMA       AL           1         63        41  US PRESIDENT
# 2   1976   ALABAMA       AL           1         63        41  US PRESIDENT
# 3   1976   ALABAMA       AL           1         63        41  US PRESIDENT
# 4   1976   ALABAMA       AL           1         63        41  US PRESIDENT
# 5   1976   ALABAMA       AL           1         63        41  US PRESIDENT
# 6   1976   ALABAMA       AL           1         63        41  US PRESIDENT
# 7   1976    ALASKA       AK           2         94        81  US PRESIDENT
# 8   1976    ALASKA       AK           2         94        81  US PRESIDENT
# 9   1976    ALASKA       AK           2         94        81  US PRESIDENT
# 10  1976    ALASKA       AK           2         94        81  US PRESIDENT
# 11  1976   ARIZONA       AZ           4         86        61  US PRESIDENT
# 12  1976   ARIZONA       AZ           4         86        61  US PRESIDENT
# 13  1976   ARIZONA       AZ           4         86        61  US PRESIDENT
# 14  1976   ARIZONA       AZ           4         86        61  US PRESIDENT
# 15  1976   ARIZONA       AZ           4         86        61  US PRESIDENT
# 16  1976   ARIZONA       AZ           4         86        61  US PRESIDENT
# 17  1976   ARIZONA       AZ           4         86        61  US PRESIDENT
# 18  1976   ARIZONA       AZ           4         86        61  US PRESIDENT
# 19  1976  ARKANSAS       AR           5         71        42  US PRESIDENT
#
#                     candidate              party_detailed  writein  \
# 0               CARTER, JIMMY                    DEMOCRAT    False
# 1                FORD, GERALD                  REPUBLICAN    False
# 2              MADDOX, LESTER  AMERICAN INDEPENDENT PARTY    False
# 3     BUBAR, BENJAMIN ""BEN""                 PROHIBITION    False
# 4                   HALL, GUS         COMMUNIST PARTY USE    False
# 5             MACBRIDE, ROGER                 LIBERTARIAN    False
# 6                         NaN                         NaN     True
# 7                FORD, GERALD                  REPUBLICAN    False
# 8               CARTER, JIMMY                    DEMOCRAT    False
# 9             MACBRIDE, ROGER                 LIBERTARIAN    False
# 10                        NaN                         NaN     True
# 11               FORD, GERALD                  REPUBLICAN    False
# 12              CARTER, JIMMY                    DEMOCRAT    False
# 13  MCCARTHY, EUGENE ""GENE""                 INDEPENDENT    False
# 14            MACBRIDE, ROGER                 LIBERTARIAN    False
# 15              CAMEJO, PETER           SOCIALIST WORKERS    False
# 16        ANDERSON, THOMAS J.                    AMERICAN    False
# 17             MADDOX, LESTER  AMERICAN INDEPENDENT PARTY    False
# 18                        NaN                         NaN     True
# 19              CARTER, JIMMY                    DEMOCRAT    False
#
#     candidatevotes  totalvotes   version  notes party_simplified
# 0           659170     1182850  20210113    NaN         DEMOCRAT
# 1           504070     1182850  20210113    NaN       REPUBLICAN
# 2             9198     1182850  20210113    NaN            OTHER
# 3             6669     1182850  20210113    NaN            OTHER
# 4             1954     1182850  20210113    NaN            OTHER
# 5             1481     1182850  20210113    NaN      LIBERTARIAN
# 6              308     1182850  20210113    NaN            OTHER
# 7            71555      123574  20210113    NaN       REPUBLICAN
# 8            44058      123574  20210113    NaN         DEMOCRAT
# 9             6785      123574  20210113    NaN      LIBERTARIAN
# 10            1176      123574  20210113    NaN            OTHER
# 11          418642      742719  20210113    NaN       REPUBLICAN
# 12          295602      742719  20210113    NaN         DEMOCRAT
# 13           19229      742719  20210113    NaN            OTHER
# 14            7647      742719  20210113    NaN      LIBERTARIAN
# 15             928      742719  20210113    NaN            OTHER
# 16             564      742719  20210113    NaN            OTHER
# 17              85      742719  20210113    NaN            OTHER
# 18              22      742719  20210113    NaN            OTHER
# 19          498604      767535  20210113    NaN         DEMOCRAT
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['state_fips'].plot(kind='hist', bins=20, title='state_fips')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['state_cen'].plot(kind='hist', bins=20, title='state_cen')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['state_ic'].plot(kind='hist', bins=20, title='state_ic')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_4.groupby('state').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_5.groupby('state_po').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_6.groupby('writein').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_7.groupby('party_simplified').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8.plot(kind='scatter', x='index', y='state_fips', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9.plot(kind='scatter', x='state_fips', y='state_cen', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10.plot(kind='scatter', x='state_cen', y='state_ic', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_11.plot(kind='scatter', x='state_ic', y='candidatevotes', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['state_cen']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_12.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('state')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='state', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('state_cen')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['state_cen']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_13.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('state_po')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='state_po', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('state_cen')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['state_cen']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_14.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('writein')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='writein', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('state_cen')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['state_cen']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_15.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('party_simplified')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='party_simplified', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('state_cen')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_16['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_17['state_fips'].plot(kind='line', figsize=(8, 4), title='state_fips')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_18['state_cen'].plot(kind='line', figsize=(8, 4), title='state_cen')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_19['state_ic'].plot(kind='line', figsize=(8, 4), title='state_ic')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['state_po'].value_counts()
#     for x_label, grp in _df_20.groupby('state')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('state')
# _ = plt.ylabel('state_po')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['writein'].value_counts()
#     for x_label, grp in _df_21.groupby('state_po')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('state_po')
# _ = plt.ylabel('writein')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['party_simplified'].value_counts()
#     for x_label, grp in _df_22.groupby('writein')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('writein')
# _ = plt.ylabel('party_simplified')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_23['state'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_23, x='index', y='state', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_24['state_po'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_24, x='index', y='state_po', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_25['writein'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_25, x='index', y='writein', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_26['party_simplified'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_26, x='index', y='party_simplified', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_7.groupby('party_simplified').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from google.colab import data_table
data_table.enable_dataframe_formatter()

df
# Out:
#     year     state state_po  state_fips  state_cen  state_ic        office  \
# 0   1976   ALABAMA       AL           1         63        41  US PRESIDENT
# 1   1976   ALABAMA       AL           1         63        41  US PRESIDENT
# 2   1976   ALABAMA       AL           1         63        41  US PRESIDENT
# 3   1976   ALABAMA       AL           1         63        41  US PRESIDENT
# 4   1976   ALABAMA       AL           1         63        41  US PRESIDENT
# 5   1976   ALABAMA       AL           1         63        41  US PRESIDENT
# 6   1976   ALABAMA       AL           1         63        41  US PRESIDENT
# 7   1976    ALASKA       AK           2         94        81  US PRESIDENT
# 8   1976    ALASKA       AK           2         94        81  US PRESIDENT
# 9   1976    ALASKA       AK           2         94        81  US PRESIDENT
# 10  1976    ALASKA       AK           2         94        81  US PRESIDENT
# 11  1976   ARIZONA       AZ           4         86        61  US PRESIDENT
# 12  1976   ARIZONA       AZ           4         86        61  US PRESIDENT
# 13  1976   ARIZONA       AZ           4         86        61  US PRESIDENT
# 14  1976   ARIZONA       AZ           4         86        61  US PRESIDENT
# 15  1976   ARIZONA       AZ           4         86        61  US PRESIDENT
# 16  1976   ARIZONA       AZ           4         86        61  US PRESIDENT
# 17  1976   ARIZONA       AZ           4         86        61  US PRESIDENT
# 18  1976   ARIZONA       AZ           4         86        61  US PRESIDENT
# 19  1976  ARKANSAS       AR           5         71        42  US PRESIDENT
#
#                     candidate              party_detailed  writein  \
# 0               CARTER, JIMMY                    DEMOCRAT    False
# 1                FORD, GERALD                  REPUBLICAN    False
# 2              MADDOX, LESTER  AMERICAN INDEPENDENT PARTY    False
# 3     BUBAR, BENJAMIN ""BEN""                 PROHIBITION    False
# 4                   HALL, GUS         COMMUNIST PARTY USE    False
# 5             MACBRIDE, ROGER                 LIBERTARIAN    False
# 6                         NaN                         NaN     True
# 7                FORD, GERALD                  REPUBLICAN    False
# 8               CARTER, JIMMY                    DEMOCRAT    False
# 9             MACBRIDE, ROGER                 LIBERTARIAN    False
# 10                        NaN                         NaN     True
# 11               FORD, GERALD                  REPUBLICAN    False
# 12              CARTER, JIMMY                    DEMOCRAT    False
# 13  MCCARTHY, EUGENE ""GENE""                 INDEPENDENT    False
# 14            MACBRIDE, ROGER                 LIBERTARIAN    False
# 15              CAMEJO, PETER           SOCIALIST WORKERS    False
# 16        ANDERSON, THOMAS J.                    AMERICAN    False
# 17             MADDOX, LESTER  AMERICAN INDEPENDENT PARTY    False
# 18                        NaN                         NaN     True
# 19              CARTER, JIMMY                    DEMOCRAT    False
#
#     candidatevotes  totalvotes   version  notes party_simplified
# 0           659170     1182850  20210113    NaN         DEMOCRAT
# 1           504070     1182850  20210113    NaN       REPUBLICAN
# 2             9198     1182850  20210113    NaN            OTHER
# 3             6669     1182850  20210113    NaN            OTHER
# 4             1954     1182850  20210113    NaN            OTHER
# 5             1481     1182850  20210113    NaN      LIBERTARIAN
# 6              308     1182850  20210113    NaN            OTHER
# 7            71555      123574  20210113    NaN       REPUBLICAN
# 8            44058      123574  20210113    NaN         DEMOCRAT
# 9             6785      123574  20210113    NaN      LIBERTARIAN
# 10            1176      123574  20210113    NaN            OTHER
# 11          418642      742719  20210113    NaN       REPUBLICAN
# 12          295602      742719  20210113    NaN         DEMOCRAT
# 13           19229      742719  20210113    NaN            OTHER
# 14            7647      742719  20210113    NaN      LIBERTARIAN
# 15             928      742719  20210113    NaN            OTHER
# 16             564      742719  20210113    NaN            OTHER
# 17              85      742719  20210113    NaN            OTHER
# 18              22      742719  20210113    NaN            OTHER
# 19          498604      767535  20210113    NaN         DEMOCRAT

# %% [markdown]
# ## Snippet

# %%
import ipywidgets as widgets

slider = widgets.IntSlider(20, min=0, max=100)
slider
# Out:
# IntSlider(value=20)

# %%
import altair as alt
import ipywidgets as widgets
from vega_datasets import data

source = data.stocks()

stock_picker = widgets.SelectMultiple(
    options=source.symbol.unique(),
    value=list(source.symbol.unique()),
    description='Symbols')

# The value of symbols will come from the stock_picker.
@widgets.interact(symbols=stock_picker)
def render(symbols):
  selected = source[source.symbol.isin(list(symbols))]

  return alt.Chart(selected).mark_line().encode(
      x='date',
      y='price',
      color='symbol',
      strokeDash='symbol',
  )
# Out:
# interactive(children=(SelectMultiple(description='Symbols', index=(0, 1, 2, 3, 4), options=('MSFT', 'AMZN', 'I…

# %%
# load an example dataset
from vega_datasets import data
cars = data.cars()

# plot the dataset, referencing dataframe column names
import altair as alt
alt.Chart(cars).mark_point().encode(
  x='Horsepower',
  y='Miles_per_Gallon',
  color='Origin'
).interactive()
# Out:
# alt.Chart(...)

# %%
# prebuilt and custom
#Jupyter Widgets

# %% [markdown]
# ## Github
#
#
# connect from setting

# %%
# prompt: write me a loop that iterates through a list called items and prints each item

items = ['a', 'b', 'c', 'd', 'e']

for item in items:
  print(item)

# %% [markdown]
# ## Extensions

# %%
## Pets

# %%
# !pip install -q -U google-generativeai

# %%
from google.colab import userdata
import google.generativeai as genai
import PIL.Image
from IPython.display import display, Image
import ipywidgets as widgets

# %%
GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')
genai.configure(api_key=GOOGLE_API_KEY)

# %%
model = genai.GenerativeModel(model_name='gemini-pro-vision')

# %%
productSketchUrl = "https://storage.googleapis.com/generativeai-downloads/images/jetpack.jpg"
# !curl -o jetpack.jpg {productSketchUrl}
img = PIL.Image.open('jetpack.jpg')
display(Image('jetpack.jpg', width=300))

# %%
analyzePrompt = """This image contains a sketch of a potential product along with some notes.
Given the product sketch, describe the product as thoroughly as possible based on what you
see in the image, making sure to note all of the product features. Return output in json format:
{description: description, features: [feature1, feature2, feature3]}"""

# %%
productInfo = eval(response.text)
print(productInfo['description'])
# Out:
# The Jetpack Backpack is a lightweight backpack that looks like a normal backpack but has a number of features that make it perfect for travel. It has a built-in USB-C charger, a 15-minute battery life, and retractable boosters that allow you to fly. The backpack is also padded for comfort and has a strap support.

# %%
response = model.generate_content([analyzePrompt, img])

# %% [markdown]
# [gemeni notebook](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Market_a_Jet_Backpack.ipynb)

# %% [markdown]
# ## Notebook ML
